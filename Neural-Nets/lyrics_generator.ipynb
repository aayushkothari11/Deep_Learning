# %%
import numpy as np
import pandas as pd
import sys 
from keras.models import Sequential
from keras.layers import LSTM, Activation, Flatten, Dropout, Dense, Embedding, TimeDistributed, CuDNNLSTM
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils
from keras.callbacks import LambdaCallback
from keras.optimizers import RMSprop, Adam
import random
import sys
import io

# %%
dataset = pd.read_csv('taylor_swift_lyrics.csv', encoding = "latin1")
dataset.head()
# Out:
#          artist         album  ... line  year
# 0  Taylor Swift  Taylor Swift  ...    1  2006
# 1  Taylor Swift  Taylor Swift  ...    2  2006
# 2  Taylor Swift  Taylor Swift  ...    3  2006
# 3  Taylor Swift  Taylor Swift  ...    4  2006
# 4  Taylor Swift  Taylor Swift  ...    5  2006
#
# [5 rows x 7 columns]

# %%
def processFirstLine(lyrics, songID, songName, row):
    lyrics.append(row['lyric'] + '\n')
    songID.append( row['year']*100+ row['track_n'])
    songName.append(row['track_title'])
    return lyrics,songID,songName

lyrics = []
songID = []
songName = []
songNumber = 1
i = 0
isFirstLine = True

for index,row in dataset.iterrows():
    if(songNumber == row['track_n']):
        if (isFirstLine):
            lyrics,songID,songName = processFirstLine(lyrics,songID,songName,row)
            isFirstLine = False
        else :  
            lyrics[i] +=  row['lyric'] + '\n'
    else :
        lyrics,songID,songName = processFirstLine(lyrics,songID,songName,row)
        songNumber = row['track_n']
        i+=1

# %%
lyrics_data = pd.DataFrame({'songID':songID, 'songName':songName, 'lyrics':lyrics })
lyrics_data.head()
# Out:
#    songID  ...                                             lyrics
# 0  200601  ...  He said the way my blue eyes shined\nPut those...
# 1  200602  ...  State the obvious, I didn't get my perfect fan...
# 2  200603  ...  Drew looks at me\nI fake a smile so he won't s...
# 3  200604  ...  I don't know what I want, so don't ask me\nCau...
# 4  200605  ...  You have a way of coming easily to me\nAnd whe...
#
# [5 rows x 3 columns]

# %%
lyricsText =''
for listitem in lyrics:
    lyricsText += listitem
    
raw_text = lyricsText # string of all lyrics
raw_text = raw_text.lower()

# %%
chars = sorted(list(set(raw_text)))  # unique characters
int_chars = dict((i, c) for i, c in enumerate(chars))
chars_int = dict((i, c) for c, i in enumerate(chars))

# %%
n_chars = len(raw_text) # length of total lyrics
n_vocab = len(chars) # no of unique characters
print(n_chars) 
print(n_vocab)
# Out:
# 173604
# 58

# %%
maxlen = 40
step = 3
sentences = []
next_chars = []

for i in range(0, len(raw_text) - maxlen, step):
    sentences.append(raw_text[i: i + maxlen])
    next_chars.append(raw_text[i + maxlen])
    
print('nb sequences:', len(sentences))
# Out:
# nb sequences: 57855

# %%
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, chars_int[char]] = 1
    y[i, chars_int[next_chars[i]]] = 1

# %%
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy', optimizer=RMSprop(lr=0.01))

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
def on_epoch_end(epoch, logs):
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(raw_text) - maxlen - 1)
    for diversity in [0.2, 0.5]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = raw_text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, chars_int[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = int_chars[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

# %%
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

history = model.fit(
    x, 
    y,
    batch_size=128,
    epochs=10,
    callbacks=[print_callback]
)
# Out:
# Epoch 1/10
# 57855/57855 [==============================] - 27s 460us/step - loss: 2.2046
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "e all the roses
# and the note that said
# o"
# e all the roses
# and the note that said
# on the been you wante the been i don't you can't be the been i made a don't for the been i me don't be the been you wand the been you some i me were be the been you sall you hand the been you hand the but i me love be the been i me look i shine starling you sand i know i don't know you some it some i made i sore the been i me don't bee some i me pore i don't be the been you some the wante be on the
# ----- diversity: 0.5
# ----- Generating with seed: "e all the roses
# and the note that said
# o"
# e all the roses
# and the note that said
# on the were light ever the the were been i wand care
# i mell be lot me gor starst of the ever the reel it in the were i never be to cou don't live i long be thin will i mond of the back i don't know you are and the wast you win thing the been you wand for me plake the never beever you than s ains be my stakever the bull a dore she never been me never shame
# i love starll be remp me you and i wand the
# Epoch 2/10
# 57855/57855 [==============================] - 26s 444us/step - loss: 1.6792
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "you think
# she's an actress, whoa
# she's b"
# you think
# she's an actress, whoa
# she's be the with you was the way the way the way a dong it the don't like i don't love you this is the don't know it my right the words the woods?
# i don't know you me of the words the wist the carled it my done it the way the sime
# i don't know it a did the way the better don't we don't the way the way the way the first like it wish you this whit you don't know you can the call the simend hear you know y
# ----- diversity: 0.5
# ----- Generating with seed: "you think
# she's an actress, whoa
# she's b"
# you think
# she's an actress, whoa
# she's been like a cands best the flocks no my (say and your this the chat i did the call the stall starle near you make a starle to you like a cored the car you we remsed i don't you could like it my right
# i know it wish you can the beet you for you was the sing thingst like a deel if the corling how we know you here you got thas the said it the mood
# i don't we can teem
# i go do me han you met me her my o
# Epoch 3/10
# 57855/57855 [==============================] - 26s 443us/step - loss: 1.4951
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "op, won't stop movin'
# it's like i got th"
# op, won't stop movin'
# it's like i got the chere in the changed
# and i love you shouldn't think i don't know it was and the chere in the call it was a sind the call it was think it was a dong the say and and i want the say a don't you wanna think i wanna be the woods?
# i'll be a ding strest the cloor the cat i live a ding and me down
# i'm think in the call it what you say i did it off i stook it was a dong and all the woods?
# are we out of t
# ----- diversity: 0.5
# ----- Generating with seed: "op, won't stop movin'
# it's like i got th"
# op, won't stop movin'
# it's like i got that i have speansien's things beck me mem
# you think i have got there hard
# and the cloor starsing and things, and there watch you're girl
# the well of the whore ther the cloor end dance strong things as the wetcress
# and i don't know
# i love the clear it all the calls the cloor first mad my fiel
# shere got in off
# i'll get then my hands in my lies
# shen you wall there starless of this is coald time
# and i
# Epoch 4/10
# 57855/57855 [==============================] - 26s 446us/step - loss: 1.3805
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "only knew me
# we could be a beautiful
# mir"
# only knew me
# we could be a beautiful
# mire
# i know is i had i had i had i had when i was the woods yet?
# are we out of the woods?
# i was out of the woods yet?
# 'cause it was a should back the place
# it's all all along the woods yet?
# are we out of the woods yet?
# are we out of the woods yet?)
# (ead i love is the prother
# we can hell the clear you can't got the storlens the woods yet?
# are we out of the woods yet?
# are we out of the woods yet?
# 'caus
# ----- diversity: 0.5
# ----- Generating with seed: "only knew me
# we could be a beautiful
# mir"
# only knew me
# we could be a beautiful
# mirate
# and i real your face
# (i'd go said it's till when you're gone
# in this love is the out it off the one when i she's now it gon a perfeet
# and i can't she wait the flace in a find first the searl
# i had i like a so call through me
# is who we'll never be to look what i said the flass lights let me, i just want to the woods yet?
# i was buck up, and i shouldn' on me
# it's all me
# i don't it now it was this
# Epoch 5/10
# 57855/57855 [==============================] - 26s 451us/step - loss: 1.2943
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "old came
# the dark days when fear crept i"
# old came
# the dark days when fear crept in the bat your starling to me
# i know is the watch the world of my the water's a might the water?
# i want to me to me made me do
# look what you want to the back to me
# i was the bat the world on my friends the world on my look that i don't know is the way the water the water and so you wanted to me had the world back to me
# i was a shake it was a things the world on my little bad to me and to make me d
# ----- diversity: 0.5
# ----- Generating with seed: "old came
# the dark days when fear crept i"
# old came
# the dark days when fear crept in the brough and my look that you're got a sirting to me
# the knows the way the games and you wanters take i have to my the world, i should thinking to me the mad the mames to you
# and i think i have to my look that you think i do that shake gones the blame that i want to the woods?
# are we were the know dress and mad my fain't what you made me do
# look what you waiting that sieved and the friends the
# Epoch 6/10
# 57855/57855 [==============================] - 26s 444us/step - loss: 1.2187
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "k
# you never let me drive
# you're a rednec"
# k
# you never let me drive
# you're a redneck and when i was straing on the mong
# and i had it was a side
# and i was a shake that you want to be the best first the sime
# i was dreaming how it was a deel so hade
# you shouldn't look it all the way you was the best of your hands all the way a simper
# and i had it was a sill the best change and i had it was a sill the mong
# and i had it was a sill it with you want to the way you want to the crow and
# ----- diversity: 0.5
# ----- Generating with seed: "k
# you never let me drive
# you're a rednec"
# k
# you never let me drive
# you're a redneck to be all the palk the wall it of stay, shines i don't know it was the way and i forget all the way stay
# what you know about you in the best dress
# never don't go nee was nicking that you're truck of your drive dancing, home we want for me, your back new york!
# it's surn and and i love what you will a dellove there, take me do
# look what you want to truc a wisting it with you
# and i had stay
# it weso
# Epoch 7/10
# 57855/57855 [==============================] - 25s 440us/step - loss: 1.1627
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "but sophistication isn't what you wear o"
# but sophistication isn't what you wear on my find with me out when you stay
# and i wanna be a dearthe said to me
# and i should be all the way a mine
# and i wanna be a dean when i wanna be the playinge lights and me the prother shine
# but i don't know is the way a silence, i wanna be a time
# i won't hear it with you
# we come back to me
# you say you wanna be here
# i won't tire the starlight
# this is the starlight
# and i wanna be a stream and me som
# ----- diversity: 0.5
# ----- Generating with seed: "but sophistication isn't what you wear o"
# but sophistication isn't what you wear on me
# and i don't let the hearlight
# you shine, had the sime
# i hear yee?
# are we out of the woods?
# you walk up, they'll tell you in the put your mying in the back
# now it could back
# and so had a till the starting and lights the prote when you're deen and i should been i don't know words that you wance the way home
# i littly beet you like a line your and on me now
# i don't leve call to you wanna be the g
# Epoch 8/10
# 57855/57855 [==============================] - 26s 442us/step - loss: 1.1226
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "ic in my mind
# saying it's gonna be alrig"
# ic in my mind
# saying it's gonna be alright if you want you calked to me the mome
# i don't wanna go the morg
# and i had i love the mophtress
# and i have been way now i have back to me the right to me on the right to me on your face to me on your face something you that in the right that i still better to dearthes
# and you said i don't like and the crowds to me of the world we can't have go think in the crow the morgless
# i'm the last time i'm
# ----- diversity: 0.5
# ----- Generating with seed: "ic in my mind
# saying it's gonna be alrig"
# ic in my mind
# saying it's gonna be alright something you make me do
# look what you got a turs
# and i should be a go
# i'll never go the right here in the right for the mony
# stay when it's alone
# and i should be a be here, now, now you've been go
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# ne back to me there all ag a fart
# and like a perfect say in the right worth the look the mought here and right for you well
# the door and round ournds thing down the day here
# and you said a love me do
#
# Epoch 9/10
# 57855/57855 [==============================] - 26s 444us/step - loss: 1.0930
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: " yet? are we out of the woods yet?
# are w"
#  yet? are we out of the woods yet?
# are we out of the woods yet? are we in the clear yet?
# do break what you made me do
# look what you made me do
# look what you made me do
# look what you think that it was the way dream
# when you're time me out of the rain
# why would back to do i don't wanna make you in the morny of the right was the mony
# but i know what you say a have of the car
# i don't wanna make you can feel the rain
# i'm true
# and the way dre
# ----- diversity: 0.5
# ----- Generating with seed: " yet? are we out of the woods yet?
# are w"
#  yet? are we out of the woods yet?
# are we out of the woods yet? are we were we know that walk we were to be the runns will people dave me hope
# i'm troude the first to be too much to my dress
# i'm dancing they don't this love you lights and ouch
# no one to be my body and night
# in the girl, dancing
# don't you stepler
# and i have been way doest from the rester that you're could remember that i had to do bad me on the back to me on the monna pa
# Epoch 10/10
# 57855/57855 [==============================] - 26s 441us/step - loss: 1.0683
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "find a place in this world
# maybe i'm jus"
# find a place in this world
# maybe i'm just a mone
# i'd be here
# i was stay
# i don't wanna to be too starlight
# said that's too had to this said how you wall
# i was scared
# can't help it when i was not the back of your face
# and i should be alright to me
# it was the way you want, call it what you want, call it what you want to you wall, i was a long on the time
# you said thinking, you say "yeah
# but i don't wanna you want, call it what you want, ca
# ----- diversity: 0.5
# ----- Generating with seed: "find a place in this world
# maybe i'm jus"
# find a place in this world
# maybe i'm just diding and of your eyes the world
# it's beathing a perfectly gone
# bet you're never better think i don't say really truels you are never wan't you wanted to be a robrd no new
# let you want, baby, i'm just alone of your face
# oh, oh
# i knew the knows that's gon't look at to be at was cried, baby, i'm just made me do
# look what you said to dever life the time
# you said made me and you're back together
# we

# %%
# 2nd model

model = Sequential()
model.add(LSTM(128,input_shape=(maxlen, len(chars)), return_sequences=True))
model.add(LSTM(128))
model.add(Dense(100, activation='relu'))
model.add(Dense(len(chars), activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
          
history = model.fit(
    x, 
    y,
    batch_size=128,
    epochs=10,
    callbacks=[print_callback]
)
# Out:
# Epoch 1/10
# 57855/57855 [==============================] - 51s 883us/step - loss: 2.9232 - acc: 0.2023
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: " trains that just aren't coming
# we show "
#  trains that just aren't coming
# we show tou sou the wou tou tou the you wou in in won in tou tou mo s no the tou toe ins that no tou wou sot the tou wou the in the tou sou toe in se tou you the tou so she tou tou wou tou wou in the cou you sou wou wou the tou the the in tou you tou the you wou soe tou woe tou in you the wou sou tou wou wou she in tou in the tou tou wou tou tou tou tou toe ann tou sou the tou sou sou tou tou thann soe wo
# ----- diversity: 0.5
# ----- Generating with seed: " trains that just aren't coming
# we show "
#  trains that just aren't coming
# we show you you tate ann s we tas hat sor tou in it and inw woun the in ghe to n wo toed the an tou she se wint you thou at ia wou bo t st n wou sad wou fane lad an go wo i dhe id tou s yee you bite ind lant il te s wat
# an le at an s soe bhe that she you de woe tels ig int yhend init tann an yhe tou mhed toos anr an me int toe
# too ind then bon ce an you lan doe it
# s wos ans n inn oo cou won be youn
# i
# s t
# Epoch 2/10
# 57855/57855 [==============================] - 49s 847us/step - loss: 2.3115 - acc: 0.3352
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "etproof
# but i'm not
# you took a swing
# i t"
# etproof
# but i'm not
# you took a swing
# i the wing thing the she and and the wang the me me be the wat the me the the wing the me i me the me wind the be the me wis the she she be the me the the me i whe me the she me the the the wing the she whet i me the the wing the the me be the be the me the wing the wing the wat the she she we the she you he me i wing you the i me be the wing the she be the me pow the wand i the dous the me be the be
# ----- diversity: 0.5
# ----- Generating with seed: "etproof
# but i'm not
# you took a swing
# i t"
# etproof
# but i'm not
# you took a swing
# i the dom thing you me le mad ce sont i me male me but she wame you dall an lass in the we we she ho cind sis and the same i thind the thind you mast you the not es sit thone the faalg be kan the me be me the net wit i call the to sris thor you thind will that i put the i she the sas thing the wo when the ale me is thanl the i coug ang me you but you whe the be the the in the le and af be hand ree do
# Epoch 3/10
# 57855/57855 [==============================] - 49s 850us/step - loss: 2.1006 - acc: 0.3839
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: " cry tears of mascara in the bathroom
# ho"
#  cry tears of mascara in the bathroom
# houre the me the me the me be the me the me the me and the say i wand the lere and the me the were the me the sall the lere the we me the me the me the me sare the sall i me the we me the shere to le me and i me the cour and the the cund the wand the me and you wand the me sall i me bat the dor you wey we me the say you were the me bat i me we last the me me the we me the care the me the leand the w
# ----- diversity: 0.5
# ----- Generating with seed: " cry tears of mascara in the bathroom
# ho"
#  cry tears of mascara in the bathroom
# houll ther to cere wo get it the werree houd to me tey lat i me ore and you heore thing to sing way be ling the talk ting the werly you with tee you beres wame ener ald be all you weelr wand ming the to me thet bove to heer and in couk you me lat you ween your and you slore you woud a cere the me me me a me it the sing the lere so dond and the tat blake the douge soud to thing the seer to kind i bus
# Epoch 4/10
# 57855/57855 [==============================] - 49s 847us/step - loss: 1.9632 - acc: 0.4198
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "nd and she's so over it
# i think her ever"
# nd and she's so over it
# i think her ever whing the sall the way whing the love the see the sing the wand i wange the light we land the sall the shere the wanker and the wand the me the way where the cander the me the love the wish the were the way where the way wher the let the all i me whing the sing the love i me thing the were the say you and you wink the were the way when the way wher the wand the here the sing the say wher the but
# ----- diversity: 0.5
# ----- Generating with seed: "nd and she's so over it
# i think her ever"
# nd and she's so over it
# i think her ever (nowh
# what wink you core wandand we coure your is and in in you shees
# and and i minge
# a ming it but the beld one in the ind so net you where hat where sall tall the shere
# thane you in the blest shay the wame the wark of where
# bignt your all go the dow a ding bus wise but you woud
# we lake the weer of the neand i donger you
# heald handand and and the gotes
# i don't hear you the call, oh the the be th
# Epoch 5/10
# 57855/57855 [==============================] - 49s 846us/step - loss: 1.8583 - acc: 0.4498
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "n the tee ball team
# you taught me about "
# n the tee ball team
# you taught me about the can the wand this the wand beer the when the wand you she the wand the stall the wand the were the light what i wat and i wand the ster the me the can the wand the wand the me the wand the say the wand the me the can the wang the wand and i me we can i don't when you wand the say the wand the way when the cand the stake the wand the lead the latting and the wand the stey it the were the wang t
# ----- diversity: 0.5
# ----- Generating with seed: "n the tee ball team
# you taught me about "
# n the tee ball team
# you taught me about me now you wand you houd you rook the wame the leald think i mick the paove got that you and and that you can the can the wound thing the can the me we can't you all me the when you this it the pight of and your the when you and got lome the way i stake and and i stind wat the wand i wan't the king the lires in the lied for thing the cand come long i me alm the can a me you love i know that on the
# Epoch 6/10
# 57855/57855 [==============================] - 49s 839us/step - loss: 1.7806 - acc: 0.4698
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: " filled with thorns
# keep you second gues"
#  filled with thorns
# keep you second gues the she shere
# and you wang the ster the starle and i hark and the want the sall the want the sall the shere
# and i don't where the can a door and i sand the way starking the say and i sall the she hare and the wand the stare and the wand the sall the where the ster the sare the sall and you wand the love and the were the like the like your wand the where and the prake and you wand you wand a me li
# ----- diversity: 0.5
# ----- Generating with seed: " filled with thorns
# keep you second gues"
#  filled with thorns
# keep you second gues in a freald whin a sees so i home, of bord some
# i hored in the pleanter back but on the sis shake sores de promes on the sall be the the sime
# and all the right prow so all the wan't he doore
# and you don't wat let what when the wauth thing that like the me i hever me to the wand hore read it of the were i love a peen and you were and the way when i hold bloke me, wo the way and i sall i know a say
# Epoch 7/10
# 57855/57855 [==============================] - 49s 839us/step - loss: 1.6880 - acc: 0.4928
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: " you go, your hand prints on my soul
# it'"
#  you go, your hand prints on my soul
# it's a let the feer it the way the all the sheart the shark the the me the me the way i don't want the sheres and i don't want the stark the way i light the say the playe the shears the sheres that i want the say the been the say it the way i know you the way i light the stark the sheres in the way i was i said the way i don't want the stark the light i want you want you all the car in the firt that
# ----- diversity: 0.5
# ----- Generating with seed: " you go, your hand prints on my soul
# it'"
#  you go, your hand prints on my soul
# it's a leat they fant the con't we me
# now you want you the pear the what
# i were the get the me the bet it the shame
# i won't we call you all in the look the all you got what you want the the make the come you look wat you wand i way a rear she shake it the alone a feel you the rear as the fees i wand you the way the net the way love on the way what i ret me
# the car i want you should be be i don't me
# y
# Epoch 8/10
# 57855/57855 [==============================] - 48s 828us/step - loss: 1.6189 - acc: 0.5127
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "fe
# i get so high, oh!
# every time you're,"
# fe
# i get so high, oh!
# every time you're, to me
# i wanna the stake the starting to me the sill the sill the sirnting the starling
# i wanna be the plain
# i was you got the say
# i was the way i sin't were you she she there the strom the starter the starle
# i've been all the sirls the sterss thing to me
# the way i don't hear the flace, i was the way the streting
# i was the starling
# the betting to me
# i know you she the stark then you the were in th
# ----- diversity: 0.5
# ----- Generating with seed: "fe
# i get so high, oh!
# every time you're,"
# fe
# i get so high, oh!
# every time you're, i'm not
# dates the ther thinging the wall of could"
# i was tho now a dreen
# and this is all all i was when you me
# i don't the flayting to the tood
# on the crears
# so me i see the where
# i'm and to bedand like the list the wand to thing afored her met the friend hears back to me me like you metin' to chand, here
# but i reall
# i could be onet my like
# you're comered soress
# you're botel and inting and out
# an
# Epoch 9/10
# 57855/57855 [==============================] - 48s 827us/step - loss: 1.5549 - acc: 0.5289
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "ydream look in your eye
# and i got that r"
# ydream look in your eye
# and i got that rook for the way what you want the way stake the start of the way what you want you stay
# i'm stark this thing that you want the way it was stream and the way what you stay
# and you want you want you want you want the way it was what the stark of the way stake the stard and you this is the way the way it was when you stay, it was the way what i was the way when you want you want the way it the way wh
# ----- diversity: 0.5
# ----- Generating with seed: "ydream look in your eye
# and i got that r"
# ydream look in your eye
# and i got that room
# and the call out that you this ast this cars me and to stard
# but i know and you want you stay
# i was the the kind you say arowhy wind you're the way and i love thing can't flake i was me off
# you had i don't rust the way home, home
# i wantad to walk the first for the way the changing the way wo be of stam
# i wanna blot you wanting the the put it wanna sime
# you this waiting you the out the way was
# Epoch 10/10
# 57855/57855 [==============================] - 48s 831us/step - loss: 1.4980 - acc: 0.5461
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "finally win
# and we'll sing hallelujah, w"
# finally win
# and we'll sing hallelujah, why we can't know there it the criend
# that i had i halk to me the was the was her the prom the proment that i had there was the start
# and i was the starts that it was the was the stards that i was the wasting they said on the cass the start of the was the plain
# he cas it the can it the strets
# and i was the change that they changed
# i was a list it was the was the can i was the was the strick ther sh
# ----- diversity: 0.5
# ----- Generating with seed: "finally win
# and we'll sing hallelujah, w"
# finally win
# and we'll sing hallelujah, whis lightt?
# i'm the cook who you wante that you're ment me, i love your pight me like me out
# oh, i know it i dight, you the pist you look that i cas cem me better hane
# 'cause out that you this ther me
# her like now
# i love a shone that whis was when you shoutthing, you onet it is in a dreanter dievers
# i love the can i don't light this me, change is wish me come to felling that has known and they sai

# %%
LSTM_layer_num = 4 
layer_size = [256,256,256,256]
model = Sequential()
model.add(CuDNNLSTM(layer_size[0], input_shape =(maxlen, len(chars)), return_sequences = True))
for i in range(1,LSTM_layer_num) :
    model.add(CuDNNLSTM(layer_size[i],return_sequences=True))
    
model.add(Flatten())
model.add(Dense(len(chars)))
model.add(Activation('softmax'))
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam')

# %%
model.fit(x,y, epochs = 10, batch_size = 128, verbose = 1, validation_split = 0.2,callbacks=[print_callback] )
# Out:
# Train on 46284 samples, validate on 11571 samples
# Epoch 1/10
# 46284/46284 [==============================] - 12s 260us/step - loss: 2.7818 - val_loss: 2.6091
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "ge that you think i'm funny 'cause he ne"
# ge that you think i'm funny 'cause he nee tee soe toa toe i oe toe eo eee you i ee tee eo ee ee he ee hee i the eee teee toe tore toe hoe to ee tea see see i me wee i i tee tia i eet i ah i ee tee i see eet toe soe tos tee eae toe toe tee see tee ee i toe toae a eta in i to ee het i ee ee see i ee tee i see tee tae see i dee tee i me teen you see thane the eee shee
# in i ee tei tee tee tae i oe hoe toae you wee toe eoe toe too tee tee ho
# ----- diversity: 0.5
# ----- Generating with seed: "ge that you think i'm funny 'cause he ne"
# ge that you think i'm funny 'cause he nerse o oit a dind you woe hote oo roe toon you eete hee i wae lowe toe wees soee soe woee
# she bese teo tea thete i mot i lme ee eo ke cea
# tese it oh ee toe teae lete ahd tee sote hotd be tea
# a i at ten if i dea tale see i me shae cie cite
# to eeeg heke you weee tee is ia ind tee coi dotl
# ald wi dee
# wore toe seeee in tee toa mor
# in roar
# med eee i in i fo ee i toae
# tou mele tee seae a lese ais
# see soe
# Epoch 2/10
# 46284/46284 [==============================] - 12s 261us/step - loss: 2.3243 - val_loss: 2.3717
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "ave the world, i'll be around
# i watch su"
# ave the world, i'll be around
# i watch sue i coun wo the cow and the you tor to cow
# the bis the linn the wen the sin the sit tot sot the sit the sin the sin the sit in the kao o ou tor the bing of you woun the sit the elo wo ow the beo the bis the bee to the coo the bee tor
# and the lot the kin to cot
# the bis the berte so the erot the wis the ee the coind the the soo the sot wo hon
# the come be the wer the be of the kis sot the soe tor to
# ----- diversity: 0.5
# ----- Generating with seed: "ave the world, i'll be around
# i watch su"
# ave the world, i'll be around
# i watch sue in foe the baot
# i want i love tue wind you raad be koet, ol wove fove as be
# then soe the ertee seree the wet tos in wlre is you
# row i te ter an the begy tee cot show wot wo me ee so oun ene
# lew sow i ot we kow how cow
# letle bae the ot oh you? sole
# you rean the cour we be see in the beike hot afd how tot so) pose at wone if wo over be and your tin ind to fey alcl or wow'he
# in the kaow thew you're
# Epoch 3/10
# 46284/46284 [==============================] - 12s 262us/step - loss: 1.9910 - val_loss: 2.2131
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "
# baby, i'm just gonna shake, shake, shak"
#
# baby, i'm just gonna shake, shake, shake, thake, that i shake
# i shoul the fot the whand the salpe sae and you the dore and the parter the you shind and the shing and the sind the sore and the fird the the sos to me whan i was the to the fis the sos the sore and the shous the soode
# "it when the the pis is the sos ther the frots
# the shot the sis the tore the sore on the sores
# you we the forler hin the bict the when so tore and feren the
# ----- diversity: 0.5
# ----- Generating with seed: "
# baby, i'm just gonna shake, shake, shak"
#
# baby, i'm just gonna shake, shake, shake, i has, sha of the fhin the suith foann mase i know makhing in's to a leoke to thin sonrearee wine to the aloting to peeing
# and thas you are the worty
# the besy the sorher
# the cour link and that leag ang whand nind and tir and the nin thame and fover in you bet i meand thas we soret, wo hey the sirlags to we the righs withr op whanging thit whes i lisht brey you whand the whe hold the we porded
# t
# Epoch 4/10
# 46284/46284 [==============================] - 12s 264us/step - loss: 1.6828 - val_loss: 2.1592
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "it's like the first time
# i fell in love "
# it's like the first time
# i fell in love you the wame the winl the reong wat the sind the sing
# the say you tas lot the gome the someng
# the whene you showd one the say that i mas in the corle so ford the sind
# could you wand the we could be you wand to co and it the same
# ohe on the sind of the raed of the fhone
# the see the could you around you when you the could bad it you all you could you wat you tall the walk we how you be all you tay i
# ----- diversity: 0.5
# ----- Generating with seed: "it's like the first time
# i fell in love "
# it's like the first time
# i fell in love wish you sale go'll go out crove it the sighpt
# the roech the fo and arling love mis
# the say thas you wate you cord around
# dondyhand in out you could the rame all the wronkening how it wo
# ded the light plaage, thear il fing epler the shone
# how the look the rights lost hight go-e of so new as the worl you wand a me out if go bveakk is hars
# shane in the car had, it the the so cone of fid it you reali
# Epoch 5/10
# 46284/46284 [==============================] - 12s 265us/step - loss: 1.3874 - val_loss: 2.1989
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "i can't explain this
# ah, ha, ha, ha-ah
# s"
# i can't explain this
# ah, ha, ha, ha-ah
# shan'i haak i know it in the swond
# ould you want the vight out of js so one
# i'm was and were
# you were me fame, and i was look one of no one staling it the sird the sird as so you dond
# the wonde like a pactels we me the with sird walk, oh, oh, oh
# you seinl the pirter know it a pistle be the sird of this is your wild in the rishreo
# thes the sonle like a showe the sther is was ho want the warled and w
# ----- diversity: 0.5
# ----- Generating with seed: "i can't explain this
# ah, ha, ha, ha-ah
# s"
# i can't explain this
# ah, ha, ha, ha-ah
# shan's anafenas, fhem what you want to know you be) with the while you would
# were ho man e ponthes and me on the stimed as me hew my heet how the will as all in of the ruet
# when you gever the portet bronk
# that it's like a ding what i 'as'le mine
# you in like at how the stald bubut don
# the kiss the won't see your the ford and for the mirh
# and i know it wish tek we the fux
# oud this tall, i wave to me
# Epoch 6/10
# 46284/46284 [==============================] - 12s 265us/step - loss: 1.0793 - val_loss: 2.2853
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "one single word they say
# and you'll leav"
# one single word they say
# and you'll leave you warcano's tome
# i know you woo't show you for thinkle at the bacs for
# in my hand when you wring
# we croone it as if lick this is now wes heretting you had that this withe the whing
# this time at sare in the said hights
# i this time hone
# could we lought out a bacsess said in my down, word
# you don't say oh oh i wans
# the stay "i had you wanna firter hanged mead me all the ligtts sord
# you say i did
# ----- diversity: 0.5
# ----- Generating with seed: "one single word they say
# and you'll leav"
# one single word they say
# and you'll leave by ingit ands
# i was a stime in the charey in a sirtod
# and nates lights gerd hantid sare freel sirlet
# the who the other this something tas my stmees
# i was hemess
# you shime a clate say and hare firhets back and on your sicdet this it thelr you hant to you
# and they wat thas wo un the sin what you wat
# and here streall could came my the kiss of that lo to back wordaud
# mad me all all high and is
# you'r
# Epoch 7/10
# 46284/46284 [==============================] - 12s 263us/step - loss: 0.7644 - val_loss: 2.5212
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "'s such a mystery
# think about the place "
# 's such a mystery
# think about the place inttigit go on through
# think it a smell on me it sccom
# dow this say that sor't go on sttring this wonded that you made and meps and be
# she i'm connd your when i'll be you looe
# you're got out i dot the sind, i lavk you around wind you've doon
# 'cause i're do on to i cond the lood with you all asd me)
# we made starlun shane lafe knew you are wish
# she and bess want that's lote i me
# for magh as me the e
# ----- diversity: 0.5
# ----- Generating with seed: "'s such a mystery
# think about the place "
# 's such a mystery
# think about the place inttas the something say my dome
# oh a gann be usssory
# you a snee hight tca tle forle as songet
# this live a spiptlicve wind youm
# welrong think it all beet the swime in the crird of on your streen
# i remember the love i could i had thes you was (than'll got by the say
# as fome made sterlt frot lost and treing the right sorg
# i wus we i wondes the prom you ferets
# well in the ond oh manne and on yoaray
# a
# Epoch 8/10
# 46284/46284 [==============================] - 12s 265us/step - loss: 0.4685 - val_loss: 2.8120
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "ut fun, this end game is the one
# with fo"
# ut fun, this end game is the one
# with fomedting coon when you wald and with mume out our maid, starnight the roind
# i don't you ever chone
# your mymeay
# and i head say should faneh, ceve your it afd tricts
# i heart wrong
# i red in your when made it a sing and chan the crimes in the storn, but of this pight lights giping on me it
# it's a long one you would
# i'm a rying be out of is gong
# so be are no out of breats we wat
# your sind
# and i heaver k
# ----- diversity: 0.5
# ----- Generating with seed: "ut fun, this end game is the one
# with fo"
# ut fun, this end game is the one
# with fomedt it call we dan
# hise you let it gond
# and you said love my hear as stirs
# and were in my nicd, wushing will we in my soing
# but i don't know what the firsels on thing, fiphteen detems
# you see the sin when it was
# here neaks ous when you're and in
# you rode the beat litets liness
# and i don't knew how it gotind
# it's toun taing a way
# i see scautirg and down, all the sires with messstines there
# i don't
# Epoch 9/10
# 46284/46284 [==============================] - 12s 269us/step - loss: 0.2346 - val_loss: 3.0779
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: " time i'm asking you this
# this is the la"
#  time i'm asking you this
# this is the last tigetiog
# thos i wond tore makes you the back atd me around
# sing we frer op to could but eale the potull
# too you bet be frees better to me the with a reaming at te me
# and i red abant the with
# and i don't know how it gots better than the
# ou this say i almoet you whet how you was foogent on it off sild and now the till the betne
# you and i took you all tho walk
# and i loved you it loued like a pege
# ----- diversity: 0.5
# ----- Generating with seed: " time i'm asking you this
# this is the la"
#  time i'm asking you this
# this is the last tiget out dome, we'lre the ow
# but i stounding the could callees so thing i head to never fod go head
# the starce the plauk, it reallp said to sead
# i know you was, to the rugit better
# go but if the beet all lot you ktmis
# me, baby, but we toog
# are we coule be you, were time if you beet you come backed the bacd and like time
# you should've berue tone you thing that a sound lave the time
# the srouss t
# Epoch 10/10
# 46284/46284 [==============================] - 12s 268us/step - loss: 0.1123 - val_loss: 3.2536
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "ever grown up
# it could still be simple
# o"
# ever grown up
# it could still be simple
# onid i've foree bicd now be the lights on
# with the out of ellla the mearn
# oh yayh see somenid thould your see and i was doon when you wat hem you and loog froen sometting is could the that stay
# he says stall the right better fhie you hadn
# this said i said like i love the oumh oo a doe hive all a
# han this love when the rains so night
# i could know it a pisele undthind
# oh you how you thing it's all h
# ----- diversity: 0.5
# ----- Generating with seed: "ever grown up
# it could still be simple
# o"
# ever grown up
# it could still be simple
# onne i've been everything a step you simlore and the veal of the singw
# oh daid to dang your drean of it
# and tellt ding
# will we forgaid if i in the ese on the ricchosen to gagcoft lith
# so made the vere for walcs wunt
# i will be how that you want bround anyn my tone
# i'd a hanne wants down
# i hope you gid that i don't know you
# and the out go facl
# the seers and when you flansing that i don't lave cors a
